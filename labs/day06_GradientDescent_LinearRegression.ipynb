# %% [markdown]
# # day06: Gradient Descent for Linear Regression
#
# # Objectives
#
# * Learn how to fit weight parameters of Linear Regression to a simple dataset via gradient descent
# * Understand impact of step size
# * Understand impact of initialization
#
#
# # Outline
# * [Part 1: Loss and Gradient for 1-dim. Linear Regression](#part1)
# * [Part 2: Gradient Descent Algorithm in a few lines of Python](#part2)
# * [Part 3: Debugging with Trace Plots](#part3)
# * [Part 4: Selecting the step size](#part4)
# * [Part 5: Selecting the initialization](#part5)
# * [Part 6: Using SciPy's built-in routines](#part6)
#
# # Takeaways
#
#
# * Gradient descent is a simple algorithm that can be implemented in a few lines of Python
#
# * Step size matters a lot
#
# * Initialization of the parameters can matter too!
#
# * scipy offers some useful tools for gradient descent
# * * "L-BFGS-B" method is highly recommended if you have your loss and gradient functions available
# * * Cannot do stochastic minibatches (requires a modest size dataset, not too big)

# %%
import numpy as np

# %%
# import plotting libraries
import matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline
plt.style.use('seaborn') # pretty matplotlib plots

import seaborn as sns
sns.set('notebook', font_scale=1.25, style='whitegrid')

# %% [markdown]
# # Create simple dataset:   y = 1.234 * x + noise

# %%
def create_dataset(N=100, slope=1.234, noise_stddev=0.1, random_state=0):
    random_state = np.random.RandomState(int(random_state))

    # input features
    x_N = np.linspace(-2, 2, N)
    
    # output features
    y_N = slope * x_N + random_state.randn(N) * noise_stddev
    
    return x_N, y_N

# %%
x_N, y_N = create_dataset(N=50, noise_stddev=0.3)

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(5,5))
plt.plot(x_N, y_N, 'k.');
plt.xlabel('x');
plt.ylabel('y');

# %% [markdown]
# # Part 1: Gradient Descent for 1-dim. Linear Regression

# %% [markdown]
# ## Define model
#
# Consider the *simplest* linear regression model. A single weight parameter $w \in \mathbb{R}$ representing the slope of the prediction line. No bias/intercept.
#
# To make predictions, we just compute the weight multiplied by the input feature
# $$
# \hat{y}(x) = w \cdot x
# $$

# %% [markdown]
# ## Define loss function

# %% [markdown]
# We want to minimize the total *squared error* across all N observed data examples (input features $x_n$, output responses $y_n$)

# %% [markdown]
# \begin{align}
#     \min_{w \in \mathbb{R}} ~~ &\ell(w)
#     \\
#     \ell(w) &= \sum_{n=1}^N (y_n - w x_n)^2
# \end{align}

# %%
def calc_loss(w):
    yhat_N = x_N * w
    sum_squared_error = np.sum(np.square(y_N - yhat_N))
    return sum_squared_error

# %%
calc_loss(2)
# Out:
# 57.757572414458366

# %% [markdown]
# # Define the gradient function
#
# \begin{align}
# \text{calc_grad}(w) = \ell'(w) &= \frac{\partial}{\partial w} [ \sum_{n=1}^N (y_n - w x_n)^2]
# \\
# &= \sum_{n=1}^N 2 (y_n - w x_n) (-x_n)
# \\
# &= 2 \sum_{n=1}^N w x_n^2 - y_n x_n
# \end{align}

# %%
def calc_grad(w):
    g = w * np.sum(np.square(x_N)) - np.sum(x_N * y_N)
    return g

# %% [markdown]
# ## Plot loss evaluated at each w from -3 to 8

# %%
w_grid = np.linspace(-3, 8, 300)

# %%
loss_grid = np.asarray([calc_loss(w) for w in w_grid])
plt.plot(w_grid, loss_grid, 'b.-');
plt.xlabel('w');
plt.ylabel('loss(w)')
# Out:
# Text(0, 0.5, 'loss(w)')

# %% [markdown]
# ### Discussion 1a: Visually, at what value of $w$ does the loss function have a minima? Is it near where you would expect (hint: look above for the "true" slope value used to generate the data)

# %% [markdown]
# ### Exercise 1b: Write NumPy code to identify which entry in the w_grid array corresponds to the lowest entry in the loss_grid array
#
# Hint: use np.argmin

# %%
# TODO write code here
print(w_grid[np.argmin(loss_grid)])
# Out:
# 1.120401337792643

# %% [markdown]
# ## Sanity check: plot gradient evaluated at each w from -3 to 8

# %%
grad_grid = np.asarray([calc_grad(w) for w in w_grid])
plt.plot(w_grid, grad_grid, 'b.-');
plt.xlabel('w');
plt.ylabel('grad(w)');

# %%
print(grad_grid)
# Out:
# [-286.44155641 -283.88882964 -281.33610286 -278.78337609 -276.23064931
#  -273.67792253 -271.12519576 -268.57246898 -266.0197422  -263.46701543
#  -260.91428865 -258.36156187 -255.8088351  -253.25610832 -250.70338155
#  -248.15065477 -245.59792799 -243.04520122 -240.49247444 -237.93974766
#  -235.38702089 -232.83429411 -230.28156733 -227.72884056 -225.17611378
#  -222.62338701 -220.07066023 -217.51793345 -214.96520668 -212.4124799
#  -209.85975312 -207.30702635 -204.75429957 -202.2015728  -199.64884602
#  -197.09611924 -194.54339247 -191.99066569 -189.43793891 -186.88521214
#  -184.33248536 -181.77975858 -179.22703181 -176.67430503 -174.12157826
#  -171.56885148 -169.0161247  -166.46339793 -163.91067115 -161.35794437
#  -158.8052176  -156.25249082 -153.69976404 -151.14703727 -148.59431049
#  -146.04158372 -143.48885694 -140.93613016 -138.38340339 -135.83067661
#  -133.27794983 -130.72522306 -128.17249628 -125.61976951 -123.06704273
#  -120.51431595 -117.96158918 -115.4088624  -112.85613562 -110.30340885
#  -107.75068207 -105.19795529 -102.64522852 -100.09250174  -97.53977497
#   -94.98704819  -92.43432141  -89.88159464  -87.32886786  -84.77614108
#   -82.22341431  -79.67068753  -77.11796076  -74.56523398  -72.0125072
#   -69.45978043  -66.90705365  -64.35432687  -61.8016001   -59.24887332
#   -56.69614654  -54.14341977  -51.59069299  -49.03796622  -46.48523944
#   -43.93251266  -41.37978589  -38.82705911  -36.27433233  -33.72160556
#   -31.16887878  -28.616152    -26.06342523  -23.51069845  -20.95797168
#   -18.4052449   -15.85251812  -13.29979135  -10.74706457   -8.19433779
#    -5.64161102   -3.08888424   -0.53615747    2.01656931    4.56929609
#     7.12202286    9.67474964   12.22747642   14.78020319   17.33292997
#    19.88565675   22.43838352   24.9911103    27.54383707   30.09656385
#    32.64929063   35.2020174    37.75474418   40.30747096   42.86019773
#    45.41292451   47.96565129   50.51837806   53.07110484   55.62383161
#    58.17655839   60.72928517   63.28201194   65.83473872   68.3874655
#    70.94019227   73.49291905   76.04564582   78.5983726    81.15109938
#    83.70382615   86.25655293   88.80927971   91.36200648   93.91473326
#    96.46746004   99.02018681  101.57291359  104.12564036  106.67836714
#   109.23109392  111.78382069  114.33654747  116.88927425  119.44200102
#   121.9947278   124.54745457  127.10018135  129.65290813  132.2056349
#   134.75836168  137.31108846  139.86381523  142.41654201  144.96926879
#   147.52199556  150.07472234  152.62744911  155.18017589  157.73290267
#   160.28562944  162.83835622  165.391083    167.94380977  170.49653655
#   173.04926333  175.6019901   178.15471688  180.70744365  183.26017043
#   185.81289721  188.36562398  190.91835076  193.47107754  196.02380431
#   198.57653109  201.12925786  203.68198464  206.23471142  208.78743819
#   211.34016497  213.89289175  216.44561852  218.9983453   221.55107208
#   224.10379885  226.65652563  229.2092524   231.76197918  234.31470596
#   236.86743273  239.42015951  241.97288629  244.52561306  247.07833984
#   249.63106662  252.18379339  254.73652017  257.28924694  259.84197372
#   262.3947005   264.94742727  267.50015405  270.05288083  272.6056076
#   275.15833438  277.71106115  280.26378793  282.81651471  285.36924148
#   287.92196826  290.47469504  293.02742181  295.58014859  298.13287537
#   300.68560214  303.23832892  305.79105569  308.34378247  310.89650925
#   313.44923602  316.0019628   318.55468958  321.10741635  323.66014313
#   326.2128699   328.76559668  331.31832346  333.87105023  336.42377701
#   338.97650379  341.52923056  344.08195734  346.63468412  349.18741089
#   351.74013767  354.29286444  356.84559122  359.398318    361.95104477
#   364.50377155  367.05649833  369.6092251   372.16195188  374.71467866
#   377.26740543  379.82013221  382.37285898  384.92558576  387.47831254
#   390.03103931  392.58376609  395.13649287  397.68921964  400.24194642
#   402.79467319  405.34739997  407.90012675  410.45285352  413.0055803
#   415.55830708  418.11103385  420.66376063  423.21648741  425.76921418
#   428.32194096  430.87466773  433.42739451  435.98012129  438.53284806
#   441.08557484  443.63830162  446.19102839  448.74375517  451.29648195
#   453.84920872  456.4019355   458.95466227  461.50738905  464.06011583
#   466.6128426   469.16556938  471.71829616  474.27102293  476.82374971]

# %% [markdown]
# ### Discussion 1c: Visually, at what value of $w$ does the gradient function cross zero? Is it the same place as the location of the minimum in the loss above?

# %% [markdown]
# TODO: Yes

# %% [markdown]
# ### Exercise 1d: Numerically, at which value of w does grad_grid cross zero?

# %%
# TODO compute with w_grid and grad_grid
idx_grad_cross_zero = np.argmin(np.abs(grad_grid))
print(w_grid[idx_grad_cross_zero])
# Out:
# 1.120401337792643

# %% [markdown]
# ## Part 2: Gradient Descent (GD) as an algorithm in Python
#
#
# ### Define minimize_via_grad_descent algorithm
#
# Can you understand what each step of this algorithm does?

# %%
def minimize_via_grad_descent(calc_loss, calc_grad, init_w=1000.0, step_size=0.001, max_iters=100):
    ''' Perform minimization of provided loss function via gradient descent
    
    Args
    ----
    calc_loss : function
    calc_grad : function
    init_w : float
    step_size : float
    max_iters : positive int
    
    Return
    ----
    wopt: array of optimized weights that approximately gives the least error
    dict with the history of loss, weight and gradient
    '''
    w = np.asarray(init_w).copy()
    grad = calc_grad(w)

    # Create some lists to track progress over time (for debugging)
    trace_loss_list = []
    trace_w_list = []
    trace_grad_list = []

    for iter_id in range(max_iters):
        if iter_id > 0:
            w = w - step_size * grad
        
        loss = calc_loss(w)
        grad = calc_grad(w)    

        print("  iter %5d/%d | loss % 13.4f | w  % 13.5f" % (iter_id, max_iters, loss, w))
    
        trace_loss_list.append(loss)
        trace_w_list.append(w)
        trace_grad_list.append(grad)
        
    wopt = w
    return wopt, dict(trace_loss_list=trace_loss_list, trace_w_list=trace_w_list, trace_grad_list=trace_grad_list)

# %% [markdown]
# ### Discussion 2a: Which line of the above function does the *parameter update* happen?
#
# Remember, in math, the parameter update of gradient descent is this:
# $$
# w \gets w - \epsilon \nabla_w \ell(w)
# $$
#
# In other words, move the parameter $w$ from its current value a *small step* in the "downhill" direction (indicated by gradient).

# %% [markdown]
# TODO: this line: w = w - step_size * grad

# %% [markdown]
# ### Try it! Run GD with step_size = 0.001

# %%
wopt, info_dict = minimize_via_grad_descent(calc_loss, calc_grad, step_size=0.001);
# Out:
#   iter     0/100 | loss  69231291.8395 | w     1000.00000
#   iter     1/100 | loss  59957009.8340 | w      930.69052
#   iter     2/100 | loss  51925118.5258 | w      866.19028
#   iter     3/100 | loss  44969186.2015 | w      806.16555
#   iter     4/100 | loss  38945076.4814 | w      750.30582
#   iter     5/100 | loss  33727961.6178 | w      698.32206
#   iter     6/100 | loss  29209735.8941 | w      649.94534
#   iter     7/100 | loss  25296775.5271 | w      604.92537
#   iter     8/100 | loss  21907998.6556 | w      563.02923
#   iter     9/100 | loss  18973185.2130 | w      524.04018
#   iter    10/100 | loss  16431521.8728 | w      487.75648
#   iter    11/100 | loss  14230341.9131 | w      453.99043
#   iter    12/100 | loss  12324033.8911 | w      422.56733
#   iter    13/100 | loss  10673096.5113 | w      393.32461
#   iter    14/100 | loss  9243320.1057 | w      366.11098
#   iter    15/100 | loss  8005077.7622 | w      340.78564
#   iter    16/100 | loss  6932711.4150 | w      317.21757
#   iter    17/100 | loss  6004000.1749 | w      295.28483
#   iter    18/100 | loss  5199699.8816 | w      274.87396
#   iter    19/100 | loss  4503144.3389 | w      255.87935
#   iter    20/100 | loss  3899899.9686 | w      238.20273
#   iter    21/100 | loss  3377466.7266 | w      221.75266
#   iter    22/100 | loss  2925019.0857 | w      206.44402
#   iter    23/100 | loss  2533181.7151 | w      192.19761
#   iter    24/100 | loss  2193835.2116 | w      178.93973
#   iter    25/100 | loss  1899947.8541 | w      166.60178
#   iter    26/100 | loss  1645429.8966 | w      155.11993
#   iter    27/100 | loss  1425007.3810 | w      144.43479
#   iter    28/100 | loss  1234112.8529 | w      134.49106
#   iter    29/100 | loss  1068790.7179 | w      125.23731
#   iter    30/100 | loss   925615.2766 | w      116.62565
#   iter    31/100 | loss   801619.7391 | w      108.61154
#   iter    32/100 | loss   694234.7492 | w      101.15350
#   iter    33/100 | loss   601235.1437 | w       94.21297
#   iter    34/100 | loss   520693.8444 | w       87.75402
#   iter    35/100 | loss   450941.9260 | w       81.74324
#   iter    36/100 | loss   390534.0338 | w       76.14954
#   iter    37/100 | loss   338218.4342 | w       70.94397
#   iter    38/100 | loss   292911.0768 | w       66.09961
#   iter    39/100 | loss   253673.1314 | w       61.59138
#   iter    40/100 | loss   219691.5346 | w       57.39597
#   iter    41/100 | loss   190262.1413 | w       53.49167
#   iter    42/100 | loss   164775.1346 | w       49.85829
#   iter    43/100 | loss   142702.3890 | w       46.47701
#   iter    44/100 | loss   123586.5271 | w       43.33035
#   iter    45/100 | loss   107031.4423 | w       40.40203
#   iter    46/100 | loss    92694.0907 | w       37.67691
#   iter    47/100 | loss    80277.3829 | w       35.14087
#   iter    48/100 | loss    69524.0279 | w       32.78080
#   iter    49/100 | loss    60211.2014 | w       30.58449
#   iter    50/100 | loss    52145.9291 | w       28.54058
#   iter    51/100 | loss    45161.0875 | w       26.63849
#   iter    52/100 | loss    39111.9412 | w       24.86839
#   iter    53/100 | loss    33873.1437 | w       23.22110
#   iter    54/100 | loss    29336.1400 | w       21.68812
#   iter    55/100 | loss    25406.9171 | w       20.26151
#   iter    56/100 | loss    22004.0563 | w       18.93389
#   iter    57/100 | loss    19057.0456 | w       17.69839
#   iter    58/100 | loss    16504.8190 | w       16.54861
#   iter    59/100 | loss    14294.4908 | w       15.47862
#   iter    60/100 | loss    12380.2600 | w       14.48287
#   iter    61/100 | loss    10722.4613 | w       13.55622
#   iter    62/100 | loss     9286.7426 | w       12.69386
#   iter    63/100 | loss     8043.3541 | w       11.89134
#   iter    64/100 | loss     6966.5309 | w       11.14450
#   iter    65/100 | loss     6033.9599 | w       10.44949
#   iter    66/100 | loss     5226.3169 | w        9.80270
#   iter    67/100 | loss     4526.8664 | w        9.20079
#   iter    68/100 | loss     3921.1149 | w        8.64065
#   iter    69/100 | loss     3396.5104 | w        8.11937
#   iter    70/100 | loss     2942.1824 | w        7.63426
#   iter    71/100 | loss     2548.7165 | w        7.18282
#   iter    72/100 | loss     2207.9596 | w        6.76270
#   iter    73/100 | loss     1912.8509 | w        6.37173
#   iter    74/100 | loss     1657.2751 | w        6.00789
#   iter    75/100 | loss     1435.9365 | w        5.66929
#   iter    76/100 | loss     1244.2486 | w        5.35419
#   iter    77/100 | loss     1078.2394 | w        5.06095
#   iter    78/100 | loss      934.4689 | w        4.78806
#   iter    79/100 | loss      809.9580 | w        4.53411
#   iter    80/100 | loss      702.1268 | w        4.29777
#   iter    81/100 | loss      608.7406 | w        4.07784
#   iter    82/100 | loss      527.8646 | w        3.87317
#   iter    83/100 | loss      457.8228 | w        3.68269
#   iter    84/100 | loss      397.1638 | w        3.50544
#   iter    85/100 | loss      344.6308 | w        3.34048
#   iter    86/100 | loss      299.1352 | w        3.18697
#   iter    87/100 | loss      259.7341 | w        3.04411
#   iter    88/100 | loss      225.6113 | w        2.91117
#   iter    89/100 | loss      196.0596 | w        2.78745
#   iter    90/100 | loss      170.4667 | w        2.67231
#   iter    91/100 | loss      148.3022 | w        2.56516
#   iter    92/100 | loss      129.1069 | w        2.46545
#   iter    93/100 | loss      112.4830 | w        2.37266
#   iter    94/100 | loss       98.0861 | w        2.28630
#   iter    95/100 | loss       85.6177 | w        2.20594
#   iter    96/100 | loss       74.8197 | w        2.13115
#   iter    97/100 | loss       65.4682 | w        2.06155
#   iter    98/100 | loss       57.3694 | w        1.99679
#   iter    99/100 | loss       50.3555 | w        1.93651

# %% [markdown]
# ### Discussion 2b: Does it appear from the *loss* values in trace above that the GD procedure converged? YES

# %% [markdown]
# ### Discussion 2c: Does it appear from the *parameter* values in trace above that the GD procedure converged?

# %% [markdown]
# ## Part 3: Diagnostic plots for gradient descent

# %% [markdown]
# Let's look at some trace functions.
#
# Whenever you run gradient descent, an *excellent* debugging strategy is the ability to plot the loss, the gradient magnitude, and the parameter of interest at every step of the algorithm.

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, sharex=True, sharey=False, figsize=(18,3.6))

axes[0].plot(info_dict['trace_loss_list']);
axes[0].set_title('loss');
axes[1].plot(info_dict['trace_grad_list']);
axes[1].set_title('grad');
axes[2].plot(info_dict['trace_w_list']);
axes[2].set_title('w');

plt.xlim([0, 100]);

# %% [markdown]
# ### Discussion 3a: What value do we expect the *loss* to converge to? Should it always be zero?

# %% [markdown]
# ### Discussion 3b: What value do we expect the *gradient* to converge to? Should it always be zero?

# %% [markdown]
# # Part 4: Larger step sizes
#
# ## Try with larger step_size = 0.02

# %%
wopt, info_dict = minimize_via_grad_descent(calc_loss, calc_grad, step_size=0.02);
# Out:
#   iter     0/100 | loss  69231291.8395 | w     1000.00000
#   iter     1/100 | loss  10409207.2378 | w     -386.18954
#   iter     2/100 | loss  1565070.4027 | w      151.31253
#   iter     3/100 | loss   235318.8835 | w      -57.10664
#   iter     4/100 | loss    35385.3981 | w       23.70896
#   iter     5/100 | loss     5324.5951 | w       -7.62770
#   iter     6/100 | loss      804.8325 | w        4.52325
#   iter     7/100 | loss      125.2680 | w       -0.18835
#   iter     8/100 | loss       23.0928 | w        1.63860
#   iter     9/100 | loss        7.7303 | w        0.93019
#   iter    10/100 | loss        5.4205 | w        1.20488
#   iter    11/100 | loss        5.0732 | w        1.09837
#   iter    12/100 | loss        5.0210 | w        1.13967
#   iter    13/100 | loss        5.0131 | w        1.12365
#   iter    14/100 | loss        5.0120 | w        1.12986
#   iter    15/100 | loss        5.0118 | w        1.12746
#   iter    16/100 | loss        5.0118 | w        1.12839
#   iter    17/100 | loss        5.0118 | w        1.12803
#   iter    18/100 | loss        5.0118 | w        1.12817
#   iter    19/100 | loss        5.0118 | w        1.12811
#   iter    20/100 | loss        5.0118 | w        1.12813
#   iter    21/100 | loss        5.0118 | w        1.12813
#   iter    22/100 | loss        5.0118 | w        1.12813
#   iter    23/100 | loss        5.0118 | w        1.12813
#   iter    24/100 | loss        5.0118 | w        1.12813
#   iter    25/100 | loss        5.0118 | w        1.12813
#   iter    26/100 | loss        5.0118 | w        1.12813
#   iter    27/100 | loss        5.0118 | w        1.12813
#   iter    28/100 | loss        5.0118 | w        1.12813
#   iter    29/100 | loss        5.0118 | w        1.12813
#   iter    30/100 | loss        5.0118 | w        1.12813
#   iter    31/100 | loss        5.0118 | w        1.12813
#   iter    32/100 | loss        5.0118 | w        1.12813
#   iter    33/100 | loss        5.0118 | w        1.12813
#   iter    34/100 | loss        5.0118 | w        1.12813
#   iter    35/100 | loss        5.0118 | w        1.12813
#   iter    36/100 | loss        5.0118 | w        1.12813
#   iter    37/100 | loss        5.0118 | w        1.12813
#   iter    38/100 | loss        5.0118 | w        1.12813
#   iter    39/100 | loss        5.0118 | w        1.12813
#   iter    40/100 | loss        5.0118 | w        1.12813
#   iter    41/100 | loss        5.0118 | w        1.12813
#   iter    42/100 | loss        5.0118 | w        1.12813
#   iter    43/100 | loss        5.0118 | w        1.12813
#   iter    44/100 | loss        5.0118 | w        1.12813
#   iter    45/100 | loss        5.0118 | w        1.12813
#   iter    46/100 | loss        5.0118 | w        1.12813
#   iter    47/100 | loss        5.0118 | w        1.12813
#   iter    48/100 | loss        5.0118 | w        1.12813
#   iter    49/100 | loss        5.0118 | w        1.12813
#   iter    50/100 | loss        5.0118 | w        1.12813
#   iter    51/100 | loss        5.0118 | w        1.12813
#   iter    52/100 | loss        5.0118 | w        1.12813
#   iter    53/100 | loss        5.0118 | w        1.12813
#   iter    54/100 | loss        5.0118 | w        1.12813
#   iter    55/100 | loss        5.0118 | w        1.12813
#   iter    56/100 | loss        5.0118 | w        1.12813
#   iter    57/100 | loss        5.0118 | w        1.12813
#   iter    58/100 | loss        5.0118 | w        1.12813
#   iter    59/100 | loss        5.0118 | w        1.12813
#   iter    60/100 | loss        5.0118 | w        1.12813
#   iter    61/100 | loss        5.0118 | w        1.12813
#   iter    62/100 | loss        5.0118 | w        1.12813
#   iter    63/100 | loss        5.0118 | w        1.12813
#   iter    64/100 | loss        5.0118 | w        1.12813
#   iter    65/100 | loss        5.0118 | w        1.12813
#   iter    66/100 | loss        5.0118 | w        1.12813
#   iter    67/100 | loss        5.0118 | w        1.12813
#   iter    68/100 | loss        5.0118 | w        1.12813
#   iter    69/100 | loss        5.0118 | w        1.12813
#   iter    70/100 | loss        5.0118 | w        1.12813
#   iter    71/100 | loss        5.0118 | w        1.12813
#   iter    72/100 | loss        5.0118 | w        1.12813
#   iter    73/100 | loss        5.0118 | w        1.12813
#   iter    74/100 | loss        5.0118 | w        1.12813
#   iter    75/100 | loss        5.0118 | w        1.12813
#   iter    76/100 | loss        5.0118 | w        1.12813
#   iter    77/100 | loss        5.0118 | w        1.12813
#   iter    78/100 | loss        5.0118 | w        1.12813
#   iter    79/100 | loss        5.0118 | w        1.12813
#   iter    80/100 | loss        5.0118 | w        1.12813
#   iter    81/100 | loss        5.0118 | w        1.12813
#   iter    82/100 | loss        5.0118 | w        1.12813
#   iter    83/100 | loss        5.0118 | w        1.12813
#   iter    84/100 | loss        5.0118 | w        1.12813
#   iter    85/100 | loss        5.0118 | w        1.12813
#   iter    86/100 | loss        5.0118 | w        1.12813
#   iter    87/100 | loss        5.0118 | w        1.12813
#   iter    88/100 | loss        5.0118 | w        1.12813
#   iter    89/100 | loss        5.0118 | w        1.12813
#   iter    90/100 | loss        5.0118 | w        1.12813
#   iter    91/100 | loss        5.0118 | w        1.12813
#   iter    92/100 | loss        5.0118 | w        1.12813
#   iter    93/100 | loss        5.0118 | w        1.12813
#   iter    94/100 | loss        5.0118 | w        1.12813
#   iter    95/100 | loss        5.0118 | w        1.12813
#   iter    96/100 | loss        5.0118 | w        1.12813
#   iter    97/100 | loss        5.0118 | w        1.12813
#   iter    98/100 | loss        5.0118 | w        1.12813
#   iter    99/100 | loss        5.0118 | w        1.12813

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, sharex=True, sharey=False, figsize=(12,3))

axes[0].plot(info_dict['trace_loss_list'], '.-');
axes[0].set_title('loss');
axes[1].plot(info_dict['trace_grad_list'], '.-');
axes[1].set_title('grad');
axes[2].plot(info_dict['trace_w_list'], '.-');
axes[2].set_title('w');

plt.xlim([0, 30]);

# %% [markdown]
# ## Try with even larger step size 0.1

# %%
wopt, info_dict = minimize_via_grad_descent(calc_loss, calc_grad, step_size=0.1, max_iters=10);
# Out:
#   iter     0/10 | loss  69231291.8395 | w     1000.00000
#   iter     1/10 | loss  2441722037.4413 | w    -5930.94768
#   iter     2/10 | loss  86117227588.5882 | w    35230.39467
#   iter     3/10 | loss  3037273198257.7529 | w  -209217.57725
#   iter     4/10 | loss  107121754144628.2344 | w   1242504.05191
#   iter     5/10 | loss  3778082991553871.5000 | w  -7378944.80700
#   iter     6/10 | loss  133249415163587200.0000 | w   43821904.53880
#   iter     7/10 | loss  4699580893572561920.0000 | w  -260248445.65768
#   iter     8/10 | loss  165749774947362701312.0000 | w   1545557103.46836
#   iter     9/10 | loss  5845837856025662717952.0000 | w  -9178716667.87204

# %% [markdown]
# ### Discussion 3b: What happens here with step size 0.1?

# %% [markdown]
# ### Exercise 3c: What is the largest step size you can get to converge reasonably?

# %%
# TODO try some other step sizes here
wopt, info_dict = minimize_via_grad_descent(calc_loss, calc_grad, step_size=0.028) # TODO fix step_size
# Out:
#   iter     0/100 | loss  69231291.8395 | w     1000.00000
#   iter     1/100 | loss  61545206.1183 | w     -940.66535
#   iter     2/100 | loss  54712432.7709 | w      889.10484
#   iter     3/100 | loss  48638236.7095 | w     -836.10705
#   iter     4/100 | loss  43238400.3741 | w      790.52130
#   iter     5/100 | loss  38438056.0726 | w     -743.15686
#   iter     6/100 | loss  34170647.9548 | w      702.88255
#   iter     7/100 | loss  30377009.2281 | w     -660.52604
#   iter     8/100 | loss  27004541.8212 | w      624.97349
#   iter     9/100 | loss  24006487.1224 | w     -587.06892
#   iter    10/100 | loss  21341277.6799 | w      555.71392
#   iter    11/100 | loss  18971960.8776 | w     -521.76705
#   iter    12/100 | loss  16865686.5937 | w      494.14358
#   iter    13/100 | loss  14993251.7405 | w     -463.71501
#   iter    14/100 | loss  13328695.3690 | w      439.40880
#   iter    15/100 | loss  11848938.7252 | w     -412.10794
#   iter    16/100 | loss  10533465.2681 | w      390.75070
#   iter    17/100 | loss  9364036.2110 | w     -366.23030
#   iter    18/100 | loss  8324437.6452 | w      347.49465
#   iter    19/100 | loss  7400255.7366 | w     -325.44602
#   iter    20/100 | loss  6578676.8806 | w      309.04089
#   iter    21/100 | loss  5848310.0445 | w     -289.18962
#   iter    22/100 | loss  5199028.8327 | w      274.85629
#   iter    23/100 | loss  4621831.0861 | w     -256.95843
#   iter    24/100 | loss  4108714.0688 | w      244.46688
#   iter    25/100 | loss  3652563.5123 | w     -228.30555
#   iter    26/100 | loss  3247054.9767 | w      217.45131
#   iter    27/100 | loss  2886566.1643 | w     -202.83373
#   iter    28/100 | loss  2566098.9669 | w      193.43502
#   iter    29/100 | loss  2281210.1687 | w     -180.18980
#   iter    30/100 | loss  2027949.8410 | w      172.08503
#   iter    31/100 | loss  1802806.5784 | w     -160.05981
#   iter    32/100 | loss  1602658.8126 | w      153.10533
#   iter    33/100 | loss  1424731.5335 | w     -142.16466
#   iter    34/100 | loss  1266557.8135 | w      136.23276
#   iter    35/100 | loss  1125944.6045 | w     -126.25624
#   iter    36/100 | loss  1000942.3314 | w      121.23339
#   iter    37/100 | loss   889817.8616 | w     -112.11397
#   iter    38/100 | loss   791030.4758 | w      107.89925
#   iter    39/100 | loss   703210.5059 | w      -99.54179
#   iter    40/100 | loss   625140.3449 | w       96.04548
#   iter    41/100 | loss   555737.5651 | w      -88.36537
#   iter    42/100 | loss   494039.9102 | w       85.50772
#   iter    43/100 | loss   439191.9541 | w      -78.42977
#   iter    44/100 | loss   390433.2405 | w       76.13986
#   iter    45/100 | loss   347087.7392 | w      -69.59722
#   iter    46/100 | loss   308554.4731 | w       67.81203
#   iter    47/100 | loss   274299.1860 | w      -61.74526
#   iter    48/100 | loss   243846.9348 | w       60.40875
#   iter    49/100 | loss   216775.5050 | w      -54.76503
#   iter    50/100 | loss   192709.5564 | w       53.82739
#   iter    51/100 | loss   171315.4192 | w      -48.55975
#   iter    52/100 | loss   152296.4678 | w       47.97670
#   iter    53/100 | loss   135389.0082 | w      -43.04338
#   iter    54/100 | loss   120358.6217 | w       42.77555
#   iter    55/100 | loss   106996.9148 | w      -38.13944
#   iter    56/100 | loss    95118.6300 | w       38.15184
#   iter    57/100 | loss    84559.0773 | w      -33.77994
#   iter    58/100 | loss    75171.8504 | w       34.04145
#   iter    59/100 | loss    66826.7973 | w      -29.90443
#   iter    60/100 | loss    59408.2154 | w       30.38740
#   iter    61/100 | loss    52813.2475 | w      -26.45919
#   iter    62/100 | loss    46950.4556 | w       27.13902
#   iter    63/100 | loss    41738.5533 | w      -23.39643
#   iter    64/100 | loss    37105.2785 | w       24.25128
#   iter    65/100 | loss    32986.3917 | w      -20.67370
#   iter    66/100 | loss    29324.7854 | w       21.68414
#   iter    67/100 | loss    26069.6922 | w      -18.25326
#   iter    68/100 | loss    23175.9807 | w       19.40200
#   iter    69/100 | loss    20603.5303 | w      -16.10153
#   iter    70/100 | loss    18316.6744 | w       17.37323
#   iter    71/100 | loss    16283.7061 | w      -14.18868
#   iter    72/100 | loss    14476.4388 | w       15.56969
#   iter    73/100 | loss    12869.8151 | w      -12.48820
#   iter    74/100 | loss    11441.5594 | w       13.96638
#   iter    75/100 | loss    10171.8692 | w      -10.97651
#   iter    76/100 | loss     9043.1405 | w       12.54108
#   iter    77/100 | loss     8039.7238 | w       -9.63265
#   iter    78/100 | loss     7147.7068 | w       11.27401
#   iter    79/100 | loss     6354.7219 | w       -8.43799
#   iter    80/100 | loss     5649.7744 | w       10.14761
#   iter    81/100 | loss     5023.0906 | w       -7.37595
#   iter    82/100 | loss     4465.9814 | w        9.14626
#   iter    83/100 | loss     3970.7228 | w       -6.43182
#   iter    84/100 | loss     3530.4479 | w        8.25608
#   iter    85/100 | loss     3139.0525 | w       -5.59252
#   iter    86/100 | loss     2791.1101 | w        7.46474
#   iter    87/100 | loss     2481.7963 | w       -4.84639
#   iter    88/100 | loss     2206.8227 | w        6.76124
#   iter    89/100 | loss     1962.3767 | w       -4.18309
#   iter    90/100 | loss     1745.0693 | w        6.13585
#   iter    91/100 | loss     1551.8874 | w       -3.59344
#   iter    92/100 | loss     1380.1526 | w        5.57989
#   iter    93/100 | loss     1227.4839 | w       -3.06925
#   iter    94/100 | loss     1091.7645 | w        5.08566
#   iter    95/100 | loss      971.1128 | w       -2.60325
#   iter    96/100 | loss      863.8559 | w        4.64629
#   iter    97/100 | loss      768.5067 | w       -2.18900
#   iter    98/100 | loss      683.7431 | w        4.25570
#   iter    99/100 | loss      608.3901 | w       -1.82073

# %% [markdown]
# # Part 5: Sensitivity to initial conditions

# %% [markdown]
# ### Exercise 5a: Try to call the defined procedure with a different initial condition for $w$. What happens?
#
# You could try $w = 5.0$ or something else.
#
# the results seem to be pretty similar, the only change is that that the plots grad and w change. The gradient instead of coming from the positive numbers towards zero, it comes from the negatives, and something similar happens with w, it converges to 1 forom above, not from below 1.

# %% [markdown]
# ### Exercise 5b: Try again with another value. Make a trace plot showing convergence from multiple different starting values for $w$. What do you notice?
#
# For example, for larger ws the convergence is slower, but it still converges.

# %% [markdown]
# # Part 6: Using scipy's built-in gradient optimization tools

# %%
import scipy.optimize

# %% [markdown]
# Take a look at SciPy's built in minimization toolbox
#
# <https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.minimize.html#scipy.optimize.minimize>
#
# We'll use "L-BFGS", a second-order method that uses the function and its gradient.

# %%
result = scipy.optimize.minimize(calc_loss, 0.0, jac=calc_grad, method='L-BFGS-B')

print(result)
# Out:
#       fun: 5.01175994382598
#  hess_inv: <1x1 LbfgsInvHessProduct with dtype=float64>
#       jac: array([1.42108547e-14])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 3
#       nit: 2
#      njev: 3
#    status: 0
#   success: True
#         x: array([1.12812831])

# %%
best_w = result.x
print(best_w)
# Out:
# [1.12812831]
